# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
# !wget --no-check-certificate \https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Out:
# --2023-11-24 15:57:49--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.24.207, 142.250.4.207, 142.251.10.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.24.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘cats_and_dogs_filtered.zip’
#
# cats_and_dogs_filte 100%[===================>]  65.43M  20.4MB/s    in 4.0s
#
# 2023-11-24 15:57:54 (16.2 MB/s) - ‘cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
# !unzip -n -q cats_and_dogs_filtered.zip

# %%
import os
base_dir = "/content/cats_and_dogs_filtered"
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'validation')

# %%
from keras.utils import image_dataset_from_directory
IMG_RES = 224
training_set = image_dataset_from_directory(train_dir, batch_size=64, image_size=(IMG_RES, IMG_RES))
val_set = image_dataset_from_directory(val_dir, batch_size=64, image_size=(IMG_RES, IMG_RES))
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for images, labels in training_set.take(1):
  for i in range(9):
    image = images[i]
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image.numpy().astype("int32"))
    label = "dog" if labels[i].numpy() == 1 else "cat"
    ax.set_title(label)
    plt.axis("off")

# %%
from keras import layers
def build_model(n, n_layers, dropout, l1=False):
  inputs = keras.Input(shape=(IMG_RES, IMG_RES, 3))
  x = layers.Rescaling(scale=1./255)(inputs)

  for _ in range(n_layers):
    x = layers.Conv2D(n, kernel_size=(3,3), activation='relu')(x)
    x = layers.Conv2D(n, kernel_size=(3,3), activation='relu')(x)
    x = layers.MaxPooling2D(pool_size=(2,2))(x)
    x = layers.Dropout(dropout)(x)

  x = layers.Flatten()(x)

  if l1:
    x = layers.Dense(n/4, activation="relu", kernel_regularization="l1")
  else:
    x = layers.Dense(n/4, activation="relu")(x)

  outputs = layers.Dense(1, activation="sigmoid")(x)

  model = keras.Model(inputs, outputs)
  model.compile(loss='binary_crossentropy',
                metrics=['accuracy'],
                optimizer='rmsprop')
  return model

# %%
model = build_model(24, 3, 0.2)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  rescaling_1 (Rescaling)     (None, 224, 224, 3)       0
#
#  conv2d_4 (Conv2D)           (None, 222, 222, 24)      672
#
#  conv2d_5 (Conv2D)           (None, 220, 220, 24)      5208
#
#  max_pooling2d_2 (MaxPoolin  (None, 110, 110, 24)      0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 110, 110, 24)      0
#
#  conv2d_6 (Conv2D)           (None, 108, 108, 24)      5208
#
#  conv2d_7 (Conv2D)           (None, 106, 106, 24)      5208
#
#  max_pooling2d_3 (MaxPoolin  (None, 53, 53, 24)        0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 53, 53, 24)        0
#
#  conv2d_8 (Conv2D)           (None, 51, 51, 24)        5208
#
#  conv2d_9 (Conv2D)           (None, 49, 49, 24)        5208
#
#  max_pooling2d_4 (MaxPoolin  (None, 24, 24, 24)        0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 24, 24, 24)        0
#
#  flatten_1 (Flatten)         (None, 13824)             0
#
#  dense_2 (Dense)             (None, 6)                 82950
#
#  dense_3 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params:
# 32/32 [==============================] - 9s 255ms/step - loss: 0.5951 - accuracy: 0.6965 - val_loss: 0.6355 - val_accuracy: 0.6310
# Epoch 17/30
# 32/32 [==============================] - 14s 362ms/step - loss: 0.5883 - accuracy: 0.6995 - val_loss: 0.6264 - val_accuracy: 0.6430
# Epoch 18/30
# 32/32 [==============================] - 11s 290ms/step - loss: 0.5780 - accuracy: 0.7150 - val_loss: 0.7045 - val_accuracy: 0.6340
# Epoch 19/30
# 32/32 [==============================] - 11s 314ms/step - loss: 0.5900 - accuracy: 0.6915 - val_loss: 0.8243 - val_accuracy: 0.6430
# Epoch 20/30
# 32/32 [==============================] - 10s 272ms/step - loss: 0.5660 - accuracy: 0.7235 - val_loss: 0.9131 - val_accuracy: 0.5770
# Epoch 21/30
# 32/32 [==============================] - 9s 253ms/step - loss: 0.5853 - accuracy: 0.7035 - val_loss: 0.6280 - val_accuracy: 0.6580
# Epoch 22/30
# 32/32 [==============================] - 7s 215ms/step - loss: 0.5468 - accuracy: 0.7480 - val_loss: 0.6539 - val_accuracy: 0.6660
# Epoch 23/30
# 32/32 [==============================] - 8s 233ms/step - loss: 0.5266 - accuracy: 0.7590 - val_loss: 0.6152 - val_accuracy: 0.6530
# Epoch 24/30
# 32/32 [==============================] - 12s 348ms/step - loss: 0.5260 - accuracy: 0.7670 - val_loss: 0.6313 - val_accuracy: 0.6670
# Epoch 25/30
# 32/32 [==============================] - 9s 225ms/step - loss: 0.5076 - accuracy: 0.7645 - val_loss: 0.6886 - val_accuracy: 0.6610
# Epoch 26/30
# 32/32 [==============================] - 8s 231ms/step - loss: 0.4999 - accuracy: 0.7765 - val_loss: 0.6220 - val_accuracy: 0.6430
# Epoch 27/30
# 32/32 [==============================] - 8s 219ms/step - loss: 0.4819 - accuracy: 0.7930 - val_loss: 0.6721 - val_accuracy: 0.6460
# Epoch 28/30
# 32/32 [==============================] - 8s 232ms/step - loss: 0.4792 - accuracy: 0.7825 - val_loss: 0.6674 - val_accuracy: 0.6600
# Epoch 29/30
# 32/32 [==============================] - 9s 255ms/step - loss: 0.4578 - accuracy: 0.8140 - val_loss: 0.9545 - val_accuracy: 0.6430
# Epoch 30/30
# 32/32 [==============================] - 8s 220ms/step - loss: 0.4574 - accuracy: 0.8110 - val_loss: 0.6116 - val_accuracy: 0.6610

# %%
plt.plot(res.history["accuracy"], label="accuracy")
plt.plot(res.history["val_accuracy"], label="val_accuracy")
plt.legend()
plt.show()

# %%
plt.plot(res.history["loss"], label="loss")
plt.plot(res.history["val_loss"], label="val_loss")
plt.legend()
plt.show()
